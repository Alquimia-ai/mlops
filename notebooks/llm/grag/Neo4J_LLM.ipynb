# %% [markdown]
# # Neo4j & Langchain Graph Retrieval Augmented Generation
#
# ### Objective:
#
# This notebooks ilustrates a way to given a certain text,generate a graph and then save into Neo4j. This should not be a productive approach, Neo4j should be hydratated through cypher queries

# %%
# !pip install graphdatascience retry==0.9.2 langchain neo4j openai -q
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Env configuration

# %%
from neo4j import GraphDatabase
import os
import json

# %%
# Neo4j configuration & constraints
neo4j_url = os.getenv("NEO4J_CONNECTION_URL")
neo4j_user = os.getenv("NEO4J_USER")
neo4j_password = os.getenv("NEO4J_PASSWORD")
gds = GraphDatabase.driver(neo4j_url, auth=(neo4j_user, neo4j_password))
gds

# %% [markdown]
# ### Prompts for LLM

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage
from string import Template

# %%
# Function to call the Mistral7b Ollama 
from langchain.callbacks.manager import CallbackManager
from langchain.chat_models import ChatOllama
from langchain.prompts import ChatPromptTemplate
from timeit import default_timer as timer
from langchain.chat_models import ChatOpenAI

chat_model = ChatOpenAI(temperature=0)

def get_chat_template(system_msg):
    chat_template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(
            content=(
               system_msg
            )
        ),
        HumanMessagePromptTemplate.from_template("{text}"),
    ]
    )
    return chat_template

# %%
products_prompt_template = """
From the Project Brief below, extract the following Entities & relationships described in the mentioned format 
 0.⁠ ⁠ALWAYS FINISH THE OUTPUT. Never send partial responses
 1.⁠ ⁠First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
   ⁠ id ⁠ property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. Document must be summarized and stored inside Project entity under ⁠ summary ⁠ property. You will have to generate as many entities as needed as per the types below:
    Entity Types:
    label:'Product',id:string,name:string //Product mentioned in the brief; ⁠ id ⁠ property is the name of the product, in lowercase, with no capital letters, special characters, spaces or hyphens; The Product is the general product which then will have in label 'type' it's different types
    label:'Gender',id:string,types:string //Gender Entity; ⁠ id ⁠ property is the gender of the product, in camel-case. Identify as many of the gender used as possible
    label:'Color',id:string,types:string //The available colors for the product; ⁠ id ⁠ property is the name of the Color or Colors, in camel-case;
    label:'Size',id:string,types:string // The available sizes for the specific porduct; ⁠ id ⁠ property are the different sizes
    label:'ProductType', id:string,name:string;summary:string //The specific product mentioned in the brief; ⁠ id ⁠ property is the name of the product, in lowercase, with no capital letters, special characters,space or hyphens; This is the type specific of a general product
    
 2.⁠ ⁠Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective ⁠ id ⁠ property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
    Relationship types:
    Product|PROVIDES|Producttype 
    ProductType|WITH|Color
    ProductType|FOR|Gender
    ProductType|IN|Size

 3.⁠ ⁠The output must look like :
{
    "entities": [{"label":"Product","id":string,"name":string],
    "relationships": ["Sweater|PROVIDES|relaxedturtleneck"] (an array of strings)
}

Case Sheet:
$ctext
"""

# %% [markdown]
# ### Process & Helpers functions

# %%
def process(chunk_prompt, system_msg):
    chat_template=get_chat_template(system_msg)
    result = chat_model(chat_template.format_messages(text=chunk_prompt))
    return result.content

# Function to take a series of chunks and a prompt template, and return a json-object of all the entities and relationships
def extract_entities_relationships(pages, prompt_template):
    start = timer()
    system_msg = "You are a helpful IT-project and account management expert who extracts information from documents."
    print(f"Running pipeline for {len(pages)} pages")
    results = []
    for document in pages:
        page_number=document.metadata.get('page')
        print(f"Extracting entities and relationships for page number: {page_number}")
        try:
           prompt = Template(prompt_template).substitute(ctext=document.page_content)
           result = process(prompt, system_msg=system_msg)
           results.append(json.loads(result))
        except Exception as e:
            print(f"Error processing  page number {page_number}")
    end = timer()
    print(f"Pipeline completed in {end-start} seconds")
    return results


# Function to take a json-object of entitites and relationships and generate cypher query for creating those entities
def generate_cypher(json_obj):
    e_statements = []
    r_statements = []

    e_label_map = {}

    # loop through our json object
    for i, obj in enumerate(json_obj):
        print(f"Generating cypher for file {i+1} of {len(json_obj)}")
        for entity in obj["entities"]:
            label = entity["label"]
            id = entity["id"]
            id = id.replace("-", "").replace("_", "")
            properties = {k: v for k, v in entity.items() if k not in ["label", "id"]}
            cypher = f'MERGE (n:{label} {{id: "{id}"}})'
            if properties:
                props_str = ", ".join(
                    [f'n.{key} = "{val}"' for key, val in properties.items()]
                )
                cypher += f" ON CREATE SET {props_str}"
            e_statements.append(cypher)
            e_label_map[id] = label
        for rs in obj["relationships"]:
            if(rs is list or isinstance(rs,str)):
                src_id, rs_type, tgt_id = rs.split("|")
                src_id = src_id.replace("-", "").replace("_", "")
                tgt_id = tgt_id.replace("-", "").replace("_", "")
                if(src_id in e_label_map and tgt_id in e_label_map):
                    src_label = e_label_map[src_id]
                    tgt_label = e_label_map[tgt_id]
                    cypher = f'MERGE (a:{src_label} {{id: "{src_id}"}}) MERGE (b:{tgt_label} {{id: "{tgt_id}"}}) MERGE (a)-[:{rs_type}]->(b)'
                    r_statements.append(cypher)
                else:
                    r_statements.append(cypher)
            else:
                print("Wrong Generated data, Try Again")
                r_statements.append("")

    with open("cyphers.txt", "w") as outfile:
        outfile.write("\n".join(e_statements + r_statements))

    return e_statements + r_statements

# Final function to bring all the steps together
def ingestion_pipeline(pages):
    # Extrating the entites and relationships from each folder, append into one json_object
    entities_relationships = []
    entities_relationships.extend(extract_entities_relationships(pages, products_prompt_template))
    # Generate and execute cypher statements
    cypher_statements = generate_cypher(entities_relationships)
    for i, stmt in enumerate(cypher_statements):
        print(f"Executing cypher statement {i+1} of {len(cypher_statements)}")
        try:
            if(stmt != ""):
                gds.execute_query(stmt)
        except Exception as e:
            with open("failed_statements.txt", "w") as f:
                f.write(f"{stmt} - Exception: {e}\n")

# %%
import ipywidgets as widgets
from IPython.display import display
import tempfile
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pydantic import BaseModel

def process_pdf(file_info):
    if not file_info:
        print("No file uploaded")
        return

    # Extract the first item in the tuple which is the file information dictionary
    file_info_dict = file_info[0]

    # Extract the content of the uploaded file
    uploaded_file_content = file_info_dict['content']

    pdf_path = ""
    with tempfile.NamedTemporaryFile(delete=False, suffix=".pdf") as temp_file:
        temp_file.write(uploaded_file_content)
        pdf_path = temp_file.name

    if pdf_path == "":
        print("File upload error")
        return

    loader = PyPDFLoader(pdf_path)
    documents=loader.load()
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=1500,
        chunk_overlap=150,
        length_function=len,
        is_separator_regex=False,
    )
    pages = splitter.split_documents(documents)
    return pages


upload_button = widgets.FileUpload(
    accept='.pdf',  # Accept only .pdf files
    multiple=False  # Allow only one file to be uploaded
)

process_button = widgets.Button(description="Process PDF")


display(upload_button)
# Out:
# FileUpload(value=(), accept='.pdf', description='Upload')

# %%
pages=process_pdf(upload_button.value)

# %%
ingestion_pipeline(pages)
# Out:
# Running pipeline for 12 pages
# Extracting entities and relationships for page number: 0
# Extracting entities and relationships for page number: 0
# Extracting entities and relationships for page number: 1
# Extracting entities and relationships for page number: 1
# Extracting entities and relationships for page number: 2
# Extracting entities and relationships for page number: 2
# Error processing  page number 2
# Extracting entities and relationships for page number: 3
# Extracting entities and relationships for page number: 3
# Error processing  page number 3
# Extracting entities and relationships for page number: 4
# Extracting entities and relationships for page number: 4
# Error processing  page number 4
# Extracting entities and relationships for page number: 5
# Extracting entities and relationships for page number: 5
# Pipeline completed in 80.17167262500152 seconds
# [{'entities': [{'label': 'Product', 'id': 'sweaters', 'name': 'Sweaters'}, {'label': 'ProductType', 'id': 'relaxedturtleneck', 'name': 'Relaxed Turtleneck'}, {'label': 'Gender', 'id': 'woman', 'types': 'Woman'}, {'label': 'Color', 'id': 'indigo', 'types': 'Indigo'}, {'label': 'Color', 'id': 'gray', 'types': 'Gray'}, {'label': 'Size', 'id': 'xs', 'types': 'XS'}, {'label': 'Size', 'id': 's', 'types': 'S'}, {'label': 'Size', 'id': 'm', 'types': 'M'}, {'label': 'Size', 'id': 'l', 'types': 'L'}, {'label': 'Size', 'id': 'xl', 'types': 'XL'}], 'relationships': ['sweaters|PROVIDES|relaxedturtleneck', 'relaxedturtleneck|WITH|indigo', 'relaxedturtleneck|WITH|gray', 'relaxedturtleneck|FOR|woman', 'relaxedturtleneck|IN|xs', 'relaxedturtleneck|IN|s', 'relaxedturtleneck|IN|m', 'relaxedturtleneck|IN|l', 'relaxedturtleneck|IN|xl']}, {'entities': [{'label': 'Product', 'id': 'sweater', 'name': 'sweater'}, {'label': 'Color', 'id': 'neutrals', 'types': 'neutrals'}, {'label': 'Color', 'id': 'hues', 'types': 'bold hues'}, {'label': 'Gender', 'id': 'feminine', 'types': 'feminine'}, {'label': 'Size', 'id': 'wide range', 'types': 'wide range'}], 'relationships': ['sweater|PROVIDES|sweater', 'sweater|WITH|neutrals', 'sweater|WITH|hues', 'sweater|FOR|feminine', 'sweater|IN|wide range']}, {'entities': [{'label': 'Product', 'id': 'relaxedturtlenecksweater', 'name': 'Relaxed Turtleneck Sweater'}, {'label': 'Product', 'id': 'droptaildownsweaterjacket', 'name': 'Drop Tail Down Sweater Jacket'}, {'label': 'Gender', 'id': 'kids', 'types': 'Kids'}, {'label': 'Color', 'id': 'black', 'types': 'Black'}, {'label': 'Color', 'id': 'blue', 'types': 'Blue'}, {'label': 'Size', 'id': 'xs', 'types': 'XS'}, {'label': 'Size', 'id': 's', 'types': 'S'}, {'label': 'Size', 'id': 'm', 'types': 'M'}, {'label': 'Size', 'id': 'l', 'types': 'L'}, {'label': 'Size', 'id': 'xl', 'types': 'XL'}, {'label': 'ProductType', 'id': 'relaxedturtlenecksweater', 'name': 'Relaxed Turtleneck Sweater', 'summary': 'Wrap yourself in the cozy elegance of the Relaxed Turtleneck Sweater - the perfect companion for winter days and nights.'}, {'label': 'ProductType', 'id': 'droptaildownsweaterjacket', 'name': 'Drop Tail Down Sweater Jacket', 'summary': 'This drop tail jacket is not only elegant but also functional, designed to keep the little ones warm during chilly days.'}], 'relationships': ['relaxedturtlenecksweater|PROVIDES|relaxedturtlenecksweater', 'relaxedturtlenecksweater|WITH|black', 'relaxedturtlenecksweater|WITH|blue', 'relaxedturtlenecksweater|FOR|kids', 'relaxedturtlenecksweater|IN|xs', 'relaxedturtlenecksweater|IN|s', 'relaxedturtlenecksweater|IN|m', 'relaxedturtlenecksweater|IN|l', 'relaxedturtlenecksweater|IN|xl', 'droptaildownsweaterjacket|PROVIDES|droptaildownsweaterjacket', 'droptaildownsweaterjacket|WITH|black', 'droptaildownsweaterjacket|WITH|blue', 'droptaildownsweaterjacket|FOR|kids', 'droptaildownsweaterjacket|IN|xs', 'droptaildownsweaterjacket|IN|s', 'droptaildownsweaterjacket|IN|m', 'droptaildownsweaterjacket|IN|l', 'droptaildownsweaterjacket|IN|xl']}, {'entities': [{'label': 'Product', 'id': 'drop-tail-down-sweater-jacket', 'name': 'Drop Tail Down Sweater Jacket'}, {'label': 'Gender', 'id': 'kids', 'types': 'Kids'}, {'label': 'Color', 'id': 'black', 'types': 'Black'}, {'label': 'Color', 'id': 'blue', 'types': 'Blue'}, {'label': 'Size', 'id': 'xs', 'types': 'XS'}, {'label': 'Size', 'id': 's', 'types': 'S'}, {'label': 'Size', 'id': 'm', 'types': 'M'}, {'label': 'Size', 'id': 'l', 'types': 'L'}, {'label': 'Size', 'id': 'xl', 'types': 'XL'}, {'label': 'ProductType', 'id': 'drop-tail-down-sweater-jacket', 'name': 'Drop Tail Down Sweater Jacket', 'summary': 'This drop tail jacket is not only elegant but also functional, designed to keep the little ones warm during chilly days.'}], 'relationships': ['drop-tail-down-sweater-jacket|FOR|kids', 'drop-tail-down-sweater-jacket|WITH|black', 'drop-tail-down-sweater-jacket|WITH|blue', 'drop-tail-down-sweater-jacket|IN|xs', 'drop-tail-down-sweat ...
# Generating cypher for file 1 of 9
# Generating cypher for file 2 of 9
# Generating cypher for file 3 of 9
# Generating cypher for file 4 of 9
# Generating cypher for file 5 of 9
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Generating cypher for file 6 of 9
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Wrong Generated data, Try Again
# Generating cypher for file 7 of 9
# Generating cypher for file 8 of 9
# Generating cypher for file 9 of 9
# Executing cypher statement 1 of 145
# Executing cypher statement 2 of 145
# Executing cypher statement 3 of 145
# Executing cypher statement 4 of 145
# Executing cypher statement 5 of 145
# Executing cypher statement 6 of 145
# Executing cypher statement 7 of 145
# Executing cypher statement 8 of 145
# Executing cypher statement 9 of 145
# Executing cypher statement 10 of 145
# Executing cypher statement 11 of 145
# Executing cypher statement 12 of 145
# Executing cypher statement 13 of 145
# Executing cypher statement 14 of 145
# Executing cypher statement 15 of 145
# Executing cypher statement 16 of 145
# Executing cypher statement 17 of 145
# Executing cypher statement 18 of 145
# Executing cypher statement 19 of 145
# Executing cypher statement 20 of 145
# Executing cypher statement 21 of 145
# Executing cypher statement 22 of 145
# Executing cypher statement 23 of 145
# Executing cypher statement 24 of 145
# Executing cypher statement 25 of 145
# Executing cypher statement 26 of 145
# Executing cypher statement 27 of 145
# Executing cypher statement 28 of 145
# Executing cypher statement 29 of 145
# Executing cypher statement 30 of 145
# Executing cypher statement 31 of 145
# Executing cypher statement 32 of 145
# Executing cypher statement 33 of 145
# Executing cypher statement 34 of 145
# Executing cypher statement 35 of 145
# Executing cypher statement 36 of 145
# Executing cypher statement 37 of 145
# Executing cypher statement 38 of 145
# Executing cypher statement 39 of 145
# Executing cypher statement 40 of 145
# Executing cypher statement 41 of 145
# Executing cypher statement 42 of 145
# Executing cypher statement 43 of 145
# Executing cypher statement 44 of 145
# Executing cypher statement 45 of 145
# Executing cypher statement 46 of 145
# Executing cypher statement 47 of 145
# Executing cypher statement 48 of 145
# Executing cypher statement 49 of 145
# Executing cypher statement 50 of 145
# Executing cypher statement 51 of 145
# Executing cypher statement 52 of 145
# Executing cypher statement 53 of 145
# Executing cypher statement 54 of 145
# Executing cypher statement 55 of 145
# Executing cypher statement 56 of 145
# Executing cypher statement 57 of 145
# Executing cypher statement 58 of 145
# Executing cypher statement 59 of 145
# Executing cypher statement 60 of 145
# Executing cypher statement 61 of 145
# Executing cypher statement 62 of 145
# Executing cypher statement 63 of 145
# Executing cypher statement 64 of 145
# Executing cypher statement 65 of 145
# Executing cypher statement 66 of 145
# Executing cypher statement 67 of 145
# Executing cypher statement 68 of 145
# Executing cypher statement 69 of 145
# Executing cypher statement 70 of 145
# Executing cypher statement 71 of 145
# Executing cypher statement 72 of 145
# Executing cypher statement 73 of 145
# Executing cypher statement 74 of 145
# Executing cypher statement 75 of 145
# Executing cypher statement 76 of 145
# Executing cypher statement 77 of 145
# Executing cypher statement 78 of 145
# Executing cypher statement 79 of 145
# Executing cypher statement 80 of 145
# Executing cypher statement 81 of 145
# Executing cypher statement 82 of 145
# Executing cypher statement 83 of 145
# Executing cypher statement 84 of 145
# Executing cypher statement 85 of 145
# Executing cypher statement 86 of 145
# Executing cypher statement 87 of 145
# Executing cypher statement 88 of 145
# Executing cypher statement 89 of 145
# Executing cypher statement 90 of 145
# Executing cypher statement 91 of 145
# Executing cypher statement 92 of 145
# Executing cypher statement 93 of 145
# Executing cypher statement 94 of 145
# Executing cypher statement 95 of 145
# Executing cypher statement 96 of 145
# Executing cypher statement 97 of 145
# Executing cypher statement 98 of 145
# Executing cypher statement 99 of 145
# Executing cypher statement 100 of 145
# Executing cypher statement 101 of 145
# Executing cypher statement 102 of 145
# Executing cypher statement 103 of 145
# Executing cypher statement 104 of 145
# Executing cypher statement 105 of 145
# Executing cypher statement 106 of 145
# Executing cypher statement 107 of 145
# Executing cypher statement 108 of 145
# Executing cypher statement 109 of 145
# Executing cypher statement 110 of 145
# Executing cypher statement 111 of 145
# Executing cypher statement 112 of 145
# Executing cypher statement 113 of 145
# Executing cypher statement 114 of 145
# Executing cypher statement 115 of 145
# Executing cypher statement 116 of 145
# Executing cypher statement 117 of 145
# Executing cypher statement 118 of 145
# Executing cypher statement 119 of 145
# Executing cypher statement 120 of 145
# Executing cypher statement 121 of 145
# Executing cypher statement 122 of 145
# Executing cypher statement 123 of 145
# Executing cypher statement 124 of 145
# Executing cypher statement 125 of 145
# Executing cypher statement 126 of 145
# Executing cypher statement 127 of 145
# Executing cypher statement 128 of 145
# Executing cypher statement 129 of 145
# Executing cypher statement 130 of 145
# Executing cypher statement 131 of 145
# Executing cypher statement 132 of 145
# Executing cypher statement 133 of 145
# Executing cypher statement 134 of 145
# Executing cypher statement 135 of 145
# Executing cypher statement 136 of 145
# Executing cypher statement 137 of 145
# Executing cypher statement 138 of 145
# Executing cypher statement 139 of 145
# Executing cypher statement 140 of 145
# Executing cypher statement 141 of 145
# Executing cypher statement 142 of 145
# Executing cypher statement 143 of 145
# Executing cypher statement 144 of 145
# Executing cypher statement 145 of 145

# %% [markdown]
# ### Play a bit with your graphs 🚀🚀

# %%
from langchain.chains import GraphCypherQAChain
from langchain.graphs import Neo4jGraph
from langchain.chat_models import ChatOllama

graph = Neo4jGraph(url=neo4j_url, username=neo4j_user,password=neo4j_password)
chain = GraphCypherQAChain.from_llm(
    ChatOllama(model="mistral-openorca:latest"), graph=graph, verbose=True,
)

# %%
chain.run("""
Which sweaters are provided? 
""")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
#  MATCH (n:Product) WHERE n.name CONTAINS "Sweater" AND NOT (n)-[:WITH]->() AND NOT (n)-[:FOR]->() AND NOT (n)-[:IN]->() RETURN n.name
# Full Context:
# [{'n.name': 'Sweaters'}, {'n.name': 'Relaxed Turtleneck Sweater'}, {'n.name': 'Drop Tail Down Sweater Jacket'}]
#
# > Finished chain.
# ' There are three types of sweaters provided: Sweaters, Relaxed Turtleneck Sweater, and Drop Tail Down Sweater Jacket.'

# %%
chain.run("""
Do you have Short-Sleeve T-Shirt with white?
""")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
#  MATCH (p:Product {name:'Short-Sleeve T-Shirt'}),
# OPTIONAL MATCH (c:Color {types: 'white'})
# WHERE (p)-[:WITH]->(c)
# RETURN p,c;
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/langchain_community/graphs/neo4j_graph.py:113, in Neo4jGraph.query(self, query, params)
#     112 try:
# --> 113     data = session.run(query, params)
#     114     return [r.data() for r in data]
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/neo4j/_sync/work/session.py:313, in Session.run(self, query, parameters, **kwargs)
#     312 parameters = dict(parameters or {}, **kwargs)
# --> 313 self._auto_result._run(
#     314     query, parameters, self._config.database,
#     315     self._config.impersonated_user, self._config.default_access_mode,
#     316     bookmarks, self._config.notifications_min_severity,
#     317     self._config.notifications_disabled_categories,
#     318 )
#     320 return self._auto_result
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/neo4j/_sync/work/result.py:181, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_categories)
#     180 self._connection.send_all()
# --> 181 self._attach()
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/neo4j/_sync/work/result.py:298, in Result._attach(self)
#     297 while self._attached is False:
# --> 298     self._connection.fetch_message()
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     177 try:
# --> 178     func(*args, **kwargs)
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:849, in Bolt.fetch_message(self)
#     846 tag, fields = self.inbox.pop(
#     847     hydration_hooks=self.responses[0].hydration_hooks
#     848 )
# --> 849 res = self._process_message(tag, fields)
#     850 self.idle_since = perf_counter()
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/neo4j/_sync/io/_bolt5.py:374, in Bolt5x0._process_message(self, tag, fields)
#     373 try:
# --> 374     response.on_failure(summary_metadata or {})
#     375 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:245, in Response.on_failure(self, metadata)
#     244 Util.callback(handler)
# --> 245 raise Neo4jError.hydrate(**metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'OPTIONAL': expected "(", "ALL", "ANY" or "SHORTEST" (line 2, column 1 (offset: 50))
# "OPTIONAL MATCH (c:Color {types: 'white'})"
#  ^}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 chain.run("""
#       2 Do you have Short-Sleeve T-Shirt with white?
#       3 """)
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/langchain/chains/base.py:507, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     505     if len(args) != 1:
#     506         raise ValueError("`run` supports only one positional argument.")
# --> 507     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508         _output_key
#     509     ]
#     511 if kwargs and not args:
#     512     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     513         _output_key
#     514     ]
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/langchain/chains/base.py:312, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
# --> 312     raise e
#     313 run_manager.on_chain_end(outputs)
#     314 final_outputs: Dict[str, Any] = self.prep_outputs(
#     315     inputs, outputs, return_only_outputs
#     316 )
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/langchain/chains/base.py:306, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     299 run_manager = callback_manager.on_chain_start(
#     300     dumpd(self),
#     301     inputs,
#     302     name=run_name,
#     303 )
#     304 try:
#     305     outputs = (
# --> 306         self._call(inputs, run_manager=run_manager)
#     307         if new_arg_supported
#     308         else self._call(inputs)
#     309     )
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/langchain/chains/graph_qa/cypher.py:267, in GraphCypherQAChain._call(self, inputs, run_manager)
#     264 # Retrieve and limit the number of results
#     265 # Generated Cypher be null if query corrector identifies invalid schema
#     266 if generated_cypher:
# --> 267     context = self.graph.query(generated_cypher)[: self.top_k]
#     268 else:
#     269     context = []
#
# File ~/Documents/software_development/projects/alquimia/mlops/venv/lib/python3.11/site-packages/langchain_community/graphs/neo4j_graph.py:116, in Neo4jGraph.query(self, query, params)
#     114     return [r.data() for r in data]
#     115 except CypherSyntaxError as e:
# --> 116     raise ValueError(f"Generated Cypher Statement is not valid\n{e}")
#
# ValueError: Generated Cypher Statement is not valid
# {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'OPTIONAL': expected "(", "ALL", "ANY" or "SHORTEST" (line 2, column 1 (offset: 50))
# "OPTIONAL MATCH (c:Color {types: 'white'})"
#  ^}
